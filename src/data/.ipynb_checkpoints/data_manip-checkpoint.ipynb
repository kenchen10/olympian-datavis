# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Just messing around with the data

# %%
data = pd.read_csv("athlete_events.csv")

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data[data["Name"] == "Christine Jacoba Aaftink"]
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
# ...

# %%
data.groupby("Age").count()
# Out:
#          ID   Name    Sex  Height  Weight   Team    NOC  Games   Year  Season  \
# Age
# 10.0      1      1      1       0       0      1      1      1      1       1
# 11.0     13     13     13       8       6     13     13     13     13      13
# 12.0     39     39     39      29      29     39     39     39     39      39
# 13.0    187    187    187     164     161    187    187    187    187     187
# 14.0    837    837    837     727     722    837    837    837    837     837
# 15.0   2203   2203   2203    1900    1881   2203   2203   2203   2203    2203
# 16.0   3852   3852   3852    3265    3207   3852   3852   3852   3852    3852
# 17.0   5376   5376   5376    4376    4306   5376   5376   5376   5376    5376
# 18.0   8152   8152   8152    6688    6583   8152   8152   8152   8152    8152
# 19.0  11643  11643  11643    9297    9191  11643  11643  11643  11643   11643
# 20.0  15258  15258  15258   12346   12200  15258  15258  15258  15258   15258
# ...

# %%
this_year = data[data["Year"] == 2016]

# %%
len(this_year)
# Out:
# 13688

# %%
fieldnames = list(data.columns)
fieldnames
# Out:
# ['ID',
#  'Name',
#  'Sex',
#  'Age',
#  'Height',
#  'Weight',
#  'Team',
#  'NOC',
#  'Games',
#  'Year',
#  'Season',
#  'City',
#  'Sport',
#  'Event',
#  'Medal']

# %%
import csv
import json

with open('athlete_events.csv') as f:
    reader = csv.DictReader(f)
    rows = list(reader)

with open('olympians.json', 'w') as f:
    json.dump(rows, f)

# %%
usa = data[data["NOC"] == "USA"]

# %%
usa.head()
# Out:
#     ID             Name Sex   Age  Height  Weight           Team  NOC  \
# 10   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 11   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 12   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 13   6  Per Knut Aaland   M  31.0   188.0    75.0  United States  USA
# 14   6  Per Knut Aaland   M  33.0   188.0    75.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 10  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 11  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 12  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 13  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 14  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                 Event Medal
# 10           Cross Country Skiing Men's 10 kilometres   NaN
# ...

# %%
usa.groupby("Year").count()
# Out:
#         ID  Name   Sex  Age  Height  Weight  Team   NOC  Games  Season  City  \
# Year
# 1896    27    27    27   27      16      13    27    27     27      27    27
# 1900   135   135   135  130      42      34   135   135    135     135   135
# 1904  1109  1109  1109  887     172     115  1109  1109   1109    1109  1109
# 1906    81    81    81   81      59      59    81    81     81      81    81
# 1908   219   219   219  214     147     141   219   219    219     219   219
# 1912   364   364   364  362     218     180   364   364    364     364   364
# 1920   473   473   473  471     305     143   473   473    473     473   473
# 1924   500   500   500  498     298     120   500   500    500     500   500
# 1928   471   471   471  451     162     128   471   471    471     471   471
# 1932   813   813   813  783     154     133   813   813    813     813   813
# 1936   561   561   561  556     138     137   561   561    561     561   561
# ...

# %%
summer = data[data["Season"] == "Summer"]

# %%
usa_summer = summer[summer["NOC"] == "USA"]

# %%
usa_summer.groupby("Year").count()
